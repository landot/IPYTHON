# %%
import csv
import pandas as pd
import numpy
import re
#from termcolor import colored
import time

# %%
df = pd.read_csv('downloads/degrees(forTimL).csv')
df.head(5)
# Out:
#    deg_branch                                      deg_title  deg_status  \
# 0           0                     BACHELOR OF ARTS (ENGLISH)           9
# 1           0  BACHELOR OF SCIENCE IN ELECTRICAL ENGINEERING           9
# 2           0                   BACHELOR OF ARTS (SOCIOLOGY)           9
# 3           0        MASTER OF EDUCATION (SPECIAL EDUCATION)           9
# 4           0        BACHELOR OF SCIENCE (COMPUTER SCIENCES)           9
#
#    deg_level  deg_earned_yr
# 0          1           2000
# 1          1           1983
# 2          1           1984
# 3          2           2004
# 4          1           1980

# %%
print(len(df))
# Out:
# 200558

# %%
df = df[df['deg_branch'] == 0]
print(len(df))
# Out:
# 193479

# %%
df = df[df['deg_status'] == 9]
print(len(df))
# Out:
# 190021

# %%
df = df[df['deg_level'] == 1]
print(len(df))
# Out:
# 124853

# %%
df = df[df['deg_earned_yr'] > 1995]
print(len(df))
# Out:
# 117447

# %%
newdf = df
#newdf['new_deg'] = [None]
newdf['new_deg'] = newdf.apply(lambda x: "", axis=1)

# %%
print(newdf.head(5))
print(newdf['deg_branch'][0])
newdf['deg_earned_yr'][0]
# Out:
#     deg_branch                                          deg_title  deg_status  \
# 0            0                         BACHELOR OF ARTS (ENGLISH)           9
# 26           0                       BACHELOR OF ARTS (SOCIOLOGY)           9
# 65           0                     BACHELOR OF ARTS (MATHEMATICS)           9
# 66           0  BACHELOR OF SCIENCE (BIOLOGY:CELL AND MOLECULA...           9
# 71           0                  BACHELOR OF ARTS (COMMUNICATIONS)           9
#
#     deg_level  deg_earned_yr new_deg
# 0           1           2000
# 26          1           2001
# 65          1           1998
# 66          1           1998
# 71          1           1996
# 0
# 2000.0

# %%
dist_Major_List = []
full_Major_Dict = {}

MajorList = sorted(set(newdf['deg_title']))



#tempdf = newdf['deg_title'],newdf['temp_deg'],newdf['new_deg']
columns = ['deg_title','temp_deg','new_deg']
tempdf = pd.DataFrame(columns=columns)

tempdf['deg_title'] = MajorList
#tempdf['new_deg'] = df.apply(lambda x: [], axis=1)

#print(tempdf.head(5))
print('test1')
print(tempdf[tempdf['deg_title'] == 'BACHELOR OF ARTS (ENGLISH)'])

temp_df_loc = tempdf[tempdf['deg_title'] == 'BACHELOR OF ARTS (ENGLISH)'].index

print('test2')
print(temp_df_loc)
# Out:
# test1
#                       deg_title temp_deg new_deg
# 803  BACHELOR OF ARTS (ENGLISH)      NaN     NaN
# test2
# Int64Index([803], dtype='int64')

# %%
#tempdf

# %%
#get a list of each individual major minus "BACHELOR OF ARTS/SCIENCE"
MajorList = sorted(set(newdf['deg_title']))

MajorList2 = []

for row in MajorList:
    dist_Major_List.append(row)
    process = row.split(" ")
    if(process[0] == 'BACHELOR' or process[0] == 'BA' or process[0] == 'BS' or process[0] == 'ACHELOR'):
        process = process[1:]
        #print(process)
    if(process[0] == 'OF' or process[0] == 'IN'):
        process = process[1:]
        #print(process)
    if(process[0] == 'FINE' or process[0] == 'ARTS' or process[0] == 'SCIENCE'):
        process = process[1:]
        #print(process)

    if(process[0] == 'FINE' or process[0] == 'ARTS' or process[0] == 'SCIENCE'):
        process = process[1:]
        #print(process)

    if(process[0] == 'IN'):
        process = process[1:] 
        
        
    str1 = ' '.join(str(e) for e in process)
    
    if('ARTS(' in str1):
        place = str1.find('ARTS(')
        str1 = str1[:place] + str1[(place + 4):]
        
    df_Ind = tempdf[tempdf['deg_title'] == row].index  
    tempdf.set_value(df_Ind ,'temp_deg', str1)
    MajorList2.append(str1)
print("")

MajorList = sorted(set(MajorList2))

# %%
#print(tempdf.head(5))

#makes new column an empty string
tempdf['new_deg'] = tempdf.apply(lambda x: "", axis=1)

# %%
#dict for full major name
for temp in dist_Major_List:
    full_Major_Dict.update({temp : None})

# %%
full_Major_Dict
# Out:
# {'BACHELOR OF ARTS (AMERICAN ETHNIC STUDIES; COMMUNICATIONS)': None,
#  'BACHELOR OF ARTS (ENGLISH; COMP. HIST OF IDEAS)': None,
#  'BA IN BUSINESS ADMINISTRATION (INFORM SYSTEMS; FINANCE)': None,
#  'BACHELOR OF ARTS (HIST & PHIL OF SCIENCE; PHILOSOPHY)': None,
#  'BACHELOR OF SCIENCE IN BUILDING CONSTRUCTION': None,
#  'BACHELOR OF ARTS (ECONOMICS;INTERDISCIPLINARY VISUAL ARTS)': None,
#  'BACHELOR OF ARTS (POLI SCI; COM; COM, ENVIR, AND PLANNING)': None,
#  'BACHELOR OF SCIENCE (BIOLOGY: ECOL, EVOL, CONSERV; ZOOLOGY)': None,
#  'BACHELOR OF ARTS (INDIVIDUALIZED STUDIES: ETHNOMUSICOLOGY)': None,
#  'BACHELOR OF SCIENCE IN FOREST RESOURCES (ESRM: LE&C)': None,
#  'BACHELOR OF ARTS IN BUSINESS ADMINISTRATION (FIN;MKTG)': None,
#  'BACHELOR OF SCIENCE (PSYCHOLOGY; ECONOMICS)': None,
#  'BACHELOR OF ARTS (COMMUNICATION, DRAMA)': None,
#  'BACHELOR OF ARTS (POL SCIENCE; AMERICAN ETHNIC STUDIES)': None,
#  'BACHELOR OF ARTS (PUBLIC HEALTH; BIOCHEMISTRY)': None,
# ...

# %%
#MajorList

# %%
#create map

deg_map = {}
for temp in MajorList:
    deg_map.update({temp : None})
print(len(deg_map))

#deg_map
# Out:
# 3130

# %%
#TEST TO SEE IF ANY DEGREE CONTAINS A SPECIFIC SUBSTRING
print(tempdf[tempdf['deg_title'].str.contains("SLAVIC")])
# Out:
#                                               deg_title  \
# 201   BACHELOR OF ARTS (C LIT: CINEMA STUDIES; SLAVI...
# 483   BACHELOR OF ARTS (COMP HIST OF IDEAS; SLAVIC L...
# 519    BACHELOR OF ARTS (COMP LIT; SLAVIC L&L: RUSSIAN)
# 575   BACHELOR OF ARTS (COMPARATIVE LIT;SLAVIC LANG ...
# 781   BACHELOR OF ARTS (ECONOMICS; SLAVIC LANGUAGES ...
# 1114         BACHELOR OF ARTS (HISTORY;SLAVIC LANGUAGE)
# 1384  BACHELOR OF ARTS (INTL ST:RUSS, E EUROPE & CEN...
# 1559  BACHELOR OF ARTS (LINGUISTICS; SLAVIC LANG & L...
# 1992  BACHELOR OF ARTS (SLAVIC LANG & LIT: RUSSIAN; ...
# 1993  BACHELOR OF ARTS (SLAVIC LANG & LIT:RUSSIAN; H...
# 1994  BACHELOR OF ARTS (SLAVIC LANG & LIT:RUSSIAN; L...
# 1995  BACHELOR OF ARTS (SLAVIC LANG & LIT:RUSSIAN;SL...
# 1996    BACHELOR OF ARTS (SLAVIC LANG & LIT; SOCIOLOGY)
# 1997  BACHELOR OF ARTS (SLAVIC LANG & LITERATURE; GE...
# 1998  BACHELOR OF ARTS (SLAVIC LANG.& LIT.; ANTHROPO...
# 1999  BACHELOR OF ARTS (SLAVIC LANGUAGES & LIT; POLI...
# ...

# %%
#tempdf

# %%
#GOES THROUGH EACH DISTINCT MAJOR AND GIVES IT AN ARRAY OF ABBREVIATED MAJORS


col = deg_map
fails = 0


for item in col:
    #old = col[index]
    major = []


    #adds undergrad majors words (list) into a string
    str1 = item

    #test duplicate cases
    if('COM' in str1 and 'COMM' not in str1):
        if('COMM' not in major):
            major.append('COMM')

    #goes through all keys to see if major contains any
    #if contains and not already in major list then it adds to list
    for key in acronym:
        if(str1.find(key) != -1):
            val = acronym.get(key, None)
            #print('Value : ' + val)
            if(val not in major):
                major.append(val)


    #test biochem, bio, chem
    if('BIOC' in major and 'BIO' in major and 'CHEM' in major):
        if(str1.count('BIO') < 2):
            major.remove('BIO')
        if(str1.count('CHEM') < 2):
            major.remove('CHEM')

    #test for biochem and bio
    if('BIOC' in major and 'BIO' in major):
        if(str1.count('BIO') < 2):
            major.remove('BIO')
    
    #test for biochem and chem
    if('BIOC' in major and 'CHEM' in major):
        if(str1.count('CHEM') < 2):
            major.remove('CHEM')

    #test for bio and neurobio
    if('BIO' in major and 'NBIO' in major):
        if(str1.count('BIO') < 2):
            major.remove('BIO')    

    #test for CHID and  History
    if('CHID' in major and 'HSTAM' in major):
        if(str1.count('HIST') < 2):
            major.remove('HSTAM')

    #test for Art history and art
    if('ART' in major and 'ART H' in major and 'HSTAM' in major):
        major.remove('HSTAM')


    #test for Art history and art
    if('ART' in major and 'ART H' in major):
        if(str1.count('ART') < 2):
            major.remove('ART')

    #test for math in acms
    if('ACMS' in major and 'MATH' in major):
        if(str1.count('MATH') < 2):
            major.remove('MATH')

    #test for IS and Info
    if('B A' in major and 'INFO' in major):
        if(str1.count('INFO') < 2):
            major.remove('INFO')

    #test for health services in clinical health services
    if('MEDXD' in major and 'HSERV' in major):
        if(str1.count('HEALTH') < 2):
            major.remove('HSERV')

    #test for comm and cep
    if('COMM' in major and 'CEP' in major):
        if(str1.count('COMM') < 2):
            major.remove('COMM')

    #test for comm in design visual communication design
    if('COMM' in major and 'DESIGN' in major):
        if(str1.count('COMM') < 2):
            major.remove('COMM')

    #test for plain engineering
    if('ENGR' in major):
        if(str1.count('ENG') > 1):
            major.remove('ENGR')

    #test for home ec vs econ
    if('ECON' in major and 'HOME' in str1):
        if(str1.count('ECON') < 2):
            major.remove('ECON')

    #test for IA in info
    if('INFO' in major and 'ARCH' in major):
        major.remove('ARCH')

    #test for sphsc in speech communication
    if('COMM' in major and 'SPHSC' in major):
        if(str1.count('SPEECH') < 2):
            major.remove('SPHSC')

    #test for soc in social work
    #FIXXXXXX (SOCIAL WORK AND SOCIOLOGY) vs (SOCIAL WORK)
    if('SOC W' in major):
        if(str1.count('SOC') < 2):
            major.remove('SOC')

    #test for music in ethnomusicology
    if('MUSIC' in major):
        if('ETHNOMUS' in str1):
            major.remove('MUSIC')
    
    #test for latin in SIS
    if('LATIN' in major):
        if('INT' in str1):
            major.remove('LATIN')
    
    #test for comm in chid
    if('CHID' in major):
        if('COMM' not in str1):
            try:
                major.remove('COMM')
            except:
                pass
    
    #test for comm in c lit
    if('C LIT' in major):
        if('COMM' not in str1):
            try:
                major.remove('COMM')
            except:
                pass
    
    #test for SOC in LSJ
    if('LSJ' in major):
        if(str1.count('SOC') < 2):
            try:
                major.remove('SOC')
            except:
                pass
            
    if('RELIG' in major):
        if(str1.count('COM') < 2):
            try:
                major.remove('COMM')
            except:
                pass
    
    if('COMPREHENSIVE' in str1):
        try:
            major.remove('COMM')
        except:
            pass
    
    if('ECONOMY' in str1 and str1.count('ECON') < 2):
        try:
            major.remove('ECON')
        except:
            pass
    
    if('CSE' in major):
        if(str1.count('COM') < 2):
            try:
                major.remove('COMM')
            except:
                pass

    if('UD&PL' in major):
        if(str1.count('COM') < 2):
            try:
                major.remove('COMM')
            except:
                pass
      
    if('HCDE' in major and 'UD&PL'):
        if(str1.count('DES') < 2):
            try:
                major.remove('UD&PL')
            except:
                pass
    
    
    if('ACMS' in major and 'COMM' in major):
        if(str1.count('COMM') < 1):
            try:
                major.remove('COMM')
            except:
                pass
    
    if('INFO' in major and 'COMM' in major):
        if(str1.count('COMM') < 1):
            try:
                major.remove('COMM')
            except:
                pass
    
    
    #MajorList.update({str1:major})
    #major_as_string = ', '.join(major) 
    
    #adds major to tempdf
    
    #df_Ind = tempdf[tempdf['temp_deg'] == item].index  
    #tempdf.set_value(df_Ind ,'new_deg', major)
    
    df_Ind = tempdf[tempdf['temp_deg'] == item].index 
    #3print('index')
    #print(df_Ind)
    
    #print(numpy.where(tempdf['temp_deg']== item)[0])
    tempind = numpy.where(tempdf['temp_deg']== item)[0]
    #print(tempdf.index.get_loc(item))
    
    
    #tempdf['new_deg'][df_Ind] = major
    
    

    #print(tempdf['new_deg'][0])
    
    for abv in major:
        var1 = tempdf['new_deg'][tempind]
        var1 = var1 + abv + ', '
        tempdf['new_deg'][tempind] = var1

    
    #adds major array to deg map
    deg_map[item] = major
    #index = index + 1

#print(fails)

# %%
tempdf
# Out:
#                                               deg_title  \
# 0     ACHELOR OF SCIENCE (APPLIED & COMP MATH SCI; C...
# 1     BA (ENVIRONMENTAL ST; COMMUNITY, ENVIRONMENT &...
# 2     BA IN  BUSINESS ADMINISTRATION (MARKETING; FIN...
# 3               BA IN BUSINESS ADMIN (ENTRE; MARKETING)
# 4      BA IN BUSINESS ADMIN (ENTREPRENEURSHIP; FINANCE)
# 5     BA IN BUSINESS ADMINISTRATION (ACCOUNTING; FIN...
# 6     BA IN BUSINESS ADMINISTRATION (ACCOUNTING; INF...
# 7     BA IN BUSINESS ADMINISTRATION (ACCOUNTING; INF...
# 8     BA IN BUSINESS ADMINISTRATION (FINANCE; ACCOUN...
# 9     BA IN BUSINESS ADMINISTRATION (FINANCE; ENTREP...
# 10    BA IN BUSINESS ADMINISTRATION (FINANCE; HR MAN...
# 11    BA IN BUSINESS ADMINISTRATION (FINANCE; INFORM...
# 12    BA IN BUSINESS ADMINISTRATION (FINANCE; MARKET...
# 13    BA IN BUSINESS ADMINISTRATION (INFO SYSTEMS; M...
# 14    BA IN BUSINESS ADMINISTRATION (INFORM SYSTEMS;...
# 15    BA IN BUSINESS ADMINISTRATION (INFORM SYSTEMS;...
# ...

# %%
count = 0
while(count < 3172):
    temp = tempdf['new_deg'][count]
    temp = temp[:-2]
    tempdf['new_deg'][count] = temp
    count = count + 1

# %%
tempdf.to_csv('Datalab_deg_list3.csv')

# %%
#GOING THROUGH EACH ROW IN THE STUDENT LIST AND ADDS THE MAJOR ARRAY ON THE NEW COLUMN

# %%
http://www.visualcomplexity.com/vc/project_details.cfm?id=951&index=951&domain=
    
http://www.visualcomplexity.com/vc/project_details.cfm?id=880&index=119&domain=Social%20Networks
    
http://vizhub.healthdata.org/gbd-compare/
    
http://www.visualcomplexity.com/vc/project_details.cfm?id=15&index=15&domain=
    
http://intensional.org/rmit_dsc/
    
http://graphics.wsj.com/food-additives-ingredients/
# Out:
#   File "<ipython-input-50-c5d93fad1a6e>", line 1
#     http://www.visualcomplexity.com/vc/project_details.cfm?id=951&index=951&domain=
#         ^
# SyntaxError: invalid syntax

# %%
acronym = {
 'ACMS': 'ACMS',
 'AERONAUTICAL & ASTRONAUTICAL ENGR': 'A A',
 'AERONAUTICAL AND ASTRONAUTICAL': 'A A',
 'AERONAUTICAL AND ASTRONAUTICAL ENGR': 'A A',
 'AERONAUTICAL ENGINEERING': 'A A',
 'AERONAUTICS & ASTRONAUTICS': 'A A',
 'AERONAUTICS AND ASTRONAUTICS': 'A A',
 'AERONAUTICS&ASTRONAUTICS': 'A A',
 'AEROSPACE ENGINEERING': 'A A',
 'AES': 'AES',
 'AFRO AMERICAN STUDIES': 'AES',
 'AFRO-AMERICAN STUDIES': 'AES',
 'AFROAMERICAN STUDIES': 'AES',
 'AFS': 'AFS',
 'AIS': 'AIS',
 'AMER ETHNIC': 'AES',
 'AMER. ETHNIC': 'AES',
 'AMER. IND': 'AIS',
 'AMERICAN ETHNIC ST': 'AES',
 'AMERICAN ETHNIC STUDIES': 'AES',
 'AMERICAN INDIAN STUD': 'AIS',
 'AMERICAN INDIAN STUDIES': 'AIS',
 'ANTH': 'ANTH',
 'ANTHR': 'ANTH',
 'ANTHROPOLOGY': 'ANTH',
 'ANTRHO': 'ANTH',
 'APP &': 'ACMS',
 'APP & COMP MATH SCI': 'ACMS',
 'APP & COMP MATH SCIENCES': 'ACMS',
 'APP.&COMP.MATH': 'ACMS',
 'APPL &': 'ACMS',
 'APPL & COMP MATH SCI': 'ACMS',
 'APPL&COMP MATH SCI': 'ACMS',
 'APPLIED & COMP': 'ACMS',
 'APPLIED & COMP MATH SCI': 'ACMS',
 'APPLIED&COMP': 'ACMS',
 'AQUATIC & FISH': 'AFS',
 'AQUATIC AND FISH': 'AFS',
 'ART HISTORY': 'ART H',
 'ARCHITECTUR': 'ARCH',
 'ART': 'ART',
 'ART HIST': 'ART H',
 'ASIAN LANG': 'ASIAN',
 'ASTRO': 'ASTRO',
 'ATM SCIENCE': 'ATM S',
 'ATMOS': 'ATM S',
 'BIO C': 'BIOC',
 'BIOC': 'BIOC',
 'BIOCHEM': 'BIOC',
 'BIOCHEMISTRY': 'BIOC',
 'BIOENG': 'BIOEN',
 'BIOL': 'BIO',
 'BIOLOGICAL AND LIFE SCIENCES': 'ACMS',
 'BIOLOGY': 'BIO',
 'BIORESOURCE SCI & ENGR': 'BSE',
 'BIORESOURCE SCIENCE AND ENGINEEERING': 'BSE',
 'BOTANY': 'BOTANY',
 'BUILDING': 'CM',
 'BUS': 'B A',
 'BUS ADM': 'B A',
 'BUSINESS ADMIN': 'B A',
 'BUSINESS ADMINISTRATION': 'B A',
 'C LIT': 'C LIT',
 'C SCI': 'CSE',
 'CEP': 'CEP',
 'CERAMIC ENGINEERING': 'MS E',
 'CERAMICS': 'ART',
 'CHEMICAL ENG': 'CHEM E',
 'CHEMICAL ENGINEERING': 'CHEM E',
 'CHEMISTR': 'CHEM',
 'CHID': 'CHID',
 'CHINA REGIONAL STUDIES': 'SIS',
 'CHINESE': 'CHIN',
 'CIVIL ENGINEERING': 'CIV E',
 'CLASSICAL STUDIES': 'CL ST',
 'CLASSICS': 'CLAS',
 'CLINICAL HEALTH SERVICES': 'MEDXD',
 'CMU': 'COMM',
 'COMM': 'COMM',
 'COMM&': 'CEP',
 'COMM,': 'CEP',
 'COMM, ENVIR, AND PLAN': 'CEP',
 'COMMUNICAT': 'COMM',
 'COMMUNICATION DISORDERS': 'SPHSC',
 'COMMUNICATIONS': 'COMM',
 'COMMUNITY & E': 'CEP',
 'COMMUNITY AND E': 'CEP',
 'COMMUNITY AND ENV': 'CEP',
 'COMMUNITY, ENVIR': 'CEP',
 'COMMUNITY, ENVIRONMENT & PLANNING': 'CEP',
 'COMMUNITY,ENVIR': 'CEP',
 'COMMUNITY;ENVIRN,& PLANNING': 'CEP',
 'COMP HIST': 'CHID',
 'COMP HIST IDEAS': 'CHID',
 'COMP HIST&IDEA': 'CHID',
 'COMP HST OF IDEAS': 'CHID',
 'COMP LIT': 'C LIT',
 'COMP SCI': 'CSE',
 'COMP SCIENCE': 'CSE',
 'COMP. HIST': 'CHID',
 'COMP. LIT': 'C LIT',
 'COMP.LIT': 'C LIT',
 'COMPARATIVE HISTORY OF IDEAS': 'CHID',
 'COMPARATIVE LIT': 'C LIT',
 'COMPARATIVE LITERATURE': 'C LIT',
 'COMPARATIVE RELIGION': 'RELIG',
 'COMPUTER EN': 'CSE',
 'COMPUTER SCI': 'CSE',
 'COMPUTER SCIENCE': 'CSE',
 'COMPUTER SCIENCES': 'CSE',
 'CONSTRUCTION MAN': 'CM',
 'COSTUME STUDIES': 'DRAMA',
 'DANCE': 'DANCE',
 'DANISH': 'DANISH',
 'DENTAL HYGIENE': 'D HYG',
 'DES &': 'UD&PL',
 'DES&': 'UD&PL',
 'DESIGN &': 'UD&PL',
 'DESIGN IN': 'DESIGN',
 'DESIGN (INTERACTION DESIGN)': 'DESIGN',
 'DESIGN STUD': 'DESIGN',
 'DESIGN VIS': 'DESIGN',
 'DESIGN&': 'UD&PL',
 'DESN&': 'UD&PL',
 'DIGITAL ARTS AND EXPER': 'DXARTS',
 'DRAMA': 'DRAMA',
 'E EURO': 'EELLC',
 'EARLY CHILD': 'ECFS',
 'EARTH & SPACE': 'ESS',
 'EARTH SC': 'ESS',
 'EAST EURO': 'EELLC',
 'EAST. EURO': 'EELLC',
 'EASTERN EURO': 'EELLC',
 'ECON': 'ECON',
 'ECONOMIC': 'ECON',
 'EDUCATION': 'EDUC',
 'EELLC': 'EELLC',
 'ELECTRICAL ENGINEERING': 'EE',
 'ENGINEERING': 'ENGR',
 'ENGL': 'ENGL',
 'ENGLISH': 'ENGL',
 'ENV & PLAN': 'CEP',
 'ENV ST': 'ENVIR',
 'ENVIR ST': 'ENVIR',
 'ENVIR SC': 'ESRM',
 'ENVIRONMENTAL SC': 'ESRM',
 'ENVIR,& PLAN': 'CEP',
 'ENVIR,PLAN': 'CEP',
 'ENVIRO & PLANNING': 'CEP',
 'ENVIRONMENT &': 'CEP',
 'ENVIRONMENT & PL': 'CEP',
 'ENVIRONMENT AND': 'CEP',
 'ENVIRONMENTAL HEALTH': 'ENV H',
 'ENVIRONMENTAL ST': 'ENVIR',
 'ESRM': 'ESRM',
 'ETHNOMUSIC': 'GEN ST',
 'FAR EASTERN': 'SIS',
 'FIBER': 'ART',
 'FINNISH': 'FINN',
 'FISHERIES': 'AFS',
 'FOREST': 'FOR R',
 'FRENCH': 'FRENCH',
 'GEN ST': 'GEN ST',
 'GEN STUDIES': 'GEN ST',
 'GEND': 'GWSS',
 'GENERAL STUDIES': 'GEN ST',
 'GEOGRAPHY': 'GEOG',
 'GEOLOGICAL SCIENCES': 'GEOL',
 'GER LAN': 'GERMAN',
 'GERMAN': 'GERMAN',
 'GRAPHIC DESIGN': 'DESIGN',
 'GREEK': 'GREEK',
 'GWSS': 'GWSS',
 'HEALTH EDUCATION': 'HSERVX',
 'HEALTH INFORMATION ADMIN' : 'PREHIA',
 'HEALTH SERVICES': 'HSERV',
 'HIST & PH': 'HPS',
 'HIST AND PH': 'HPS',
 'HISTORY': 'HSTAM',
 'HUMAN C': 'HCDE',
 'HUMANIT': 'HUMAN',
 'INDIV': 'INDIV',
 'INDIVIDUALIZED STUDIES': 'INDIV',
 'INDUSTRIAL DESIGN': 'ART',
 'INDUSTRIAL ENGINEERING': 'IND E',
 'INFO ': 'INFO',
 'INFORMATICS': 'INFO',
 'INT ST': 'SIS',
 "INT'L ST": 'SIS',
 'INTER ST': 'SIS',
 'INTERDISCIPLINARY ENGR': 'INT EN',
 'INTERDISCIPLINARY VISUAL ARTS': 'ART',
 'INTERIOR DESIGN': 'ART',
 'INTERL': 'SIS',
 'INTERL STUDIES': 'SIS',
 'INTERNATL': 'SIS',
 "INTERNAT'L STUD": 'SIS',
 'INTERNATIONAL ST': 'SIS',
 'INTERNATONAL': 'SIS',
 'INTERNL STU': 'SIS',
 'INTERNL STUDIES': 'SIS',
 'INTL ST': 'SIS',
 'INTL STUDIES': 'SIS',
 'INTL.': 'SIS',
 'INTNL' : 'SIS',
 'INTRL': 'SIS',
 'INTRN': 'SIS',
 'ITALIAN': 'ITAL',
 'JAPAN': 'JAPAN',
 'JAPANESE': 'JAPAN',
 'JOURNALISM': 'COMM',
 'JSIS': 'SIS',
 'KOREAN': 'KOREAN',
 'LANDSCAPE ARCHITECTURE': 'L ARCH',
 'LATIN': 'LATIN',
 'LAW, SOC': 'LSJ',
 'LAW, SOCIETIES': 'LSJ',
 'LAW,SOC': 'LSJ',
 'LINGUISTICS': 'LING',
 'LSJ': 'LSJ',
 'MARKETING': 'B A',
 'MAT SCI': 'MS E',
 'MATERIALS SCI': 'MS E',
 'MATH': 'MATH',
 'MATHEMATICS': 'MATH',
 'MECHANICAL ENG': 'M E',
 'MEDICAL TECHNOLOGY': 'MED T',
 'METAL DESIGN': 'ART',
 'METALLURG': 'MS E',
 'METALS': 'ART',
 'MICROBIOLOGY': 'MICROM',
 'MUSIC': 'MUSIC',
 'NATURAL S': 'NAT SCI',
 'NEAR E STU': 'NEAR E',
 'NEAR EAST': 'NEAR E',
 'NEAR EAST LANG': 'NEAR E',
 'NEAR EAST ST': 'N&MES',
 'NEAR EASTERN CIV': 'NEAR E',
 'NEAR EASTERN LANG & CIV': 'NEAR E',
 'NEAR EASTERN ST': 'N&MES',
 'NEAR EASTN STUDIES': 'N&MES',
 'NEUROBIOLOGY': 'NBIO',
 'NORWEGIAN': 'NORW',
 'NURSING': 'NURS',
 'NUTRITIONA': 'NUTR',
 'OCCUPATIONAL THERAPY': 'REHAB',
 'OCEANOGRAPHY': 'OCEAN',
 'PAINTING': 'ART',
 'PAPER SCIENCE': 'BSE',
 'PHARMACY': 'PHARM',
 'PHILOSOPHY': 'PHIL',
 'PHOTOGRAPHY': 'ART',
 'PHOTOMEDIA': 'ART',
 'PHYSICAL THERAPY': 'REHAB',
 'PHYSICS': 'PHYS',
 'POL S': 'POL S',
 'POLI SCI': 'POL S',
 'POLITICAL SCI': 'POL S',
 'POLITICAL SCIENCE': 'POL S',
 'PRINT MAKING': 'ART',
 'PRINTMAKING': 'ART',
 'PROSTHE': 'REHAB',
 'PSYCH': 'PSYCH',
 'PSYCHOLOGY': 'PSYCH',
 'PUBLIC HEALTH': 'PH',
 'RELIG': 'RELIG',
 'ROMANCE LINGUISTICS': 'ROM LI',
 'RUSS': 'RUSS',
 'RUSS LANG': 'RUSS',
 'RUSSIAN LANG': 'RUSS',
 'SCAN': 'SCAND',
 'SCAND AREA STUDIES': 'SCAND',
 'SCANDINAVIAN STUDIES': 'SCAND',
 'SCULPTURE': 'ART',
 'SIS': 'SIS',
 'SISA': 'SIS',
 'SLAVIC L&L': 'SLAVIC',
 'SLAVIC LANGUAGES & LIT': 'SLAVIC',
 'SLAVIC LANGUAGES & LITERATURES': 'SLAVIC',
 'SLAVIC LANGUAGES AND LITERATURE': 'SLAVIC',
 'SLAVIC LANG': 'SLAVIC',
 'SOC': 'SOC',
 'SOC & JUST': 'LSJ',
 'SOC&JUST': 'LSJ',
 'SOCIAL WELFARE': 'SOC WL',
 'SOCIAL WORK': 'SOC W',
 'SOCIETY & JUSTICE': 'LSJ',
 'SOCIETY AND JUSTICE': 'LSJ',
 'SOCIOLOGY': 'SOC',
 'SPANISH': 'SPAN',
 'SPCH': 'SPHSC',
 'SPEECH': 'SPHSC',
 'SPEECH & HEAR': 'SPHSC',
 'SPEECH AND HEAR': 'SPHSC',
 'SPEECH COMMUNICATION': 'COMM',
 'SPEECH&': 'SPHSC',
 'STAT': 'STAT',
 'STATISTICS': 'STAT',
 'SWEDISH': 'SWED',
 'THREE DIMENSION': 'ART',
 'URBAN PLANNING': 'UD&PL',
 'WOMEN STUDIES': 'GWSS',
 'ZOOLOGY': 'ZOOL',
 'WILDLIFE': 'FOR R'
}
